# %% [markdown]
# [![Open In Colab](../notebooks/colab-badge.png)](https://colab.research.google.com/github/zoldbirka/colab-test-pub/blob/master/02_sol_PythonBev_kollekciok_URES.ipynb)

# %% [markdown]
# # Gyűjtemények; Konverziós lehetőségek; Adat beolvasás és kiíratás
#
# Gyűjtemények (Kollekciók): lista, tuple, szótár, halmaz. Ezek tulajdonságai. Indexelése.
#
# Konverziós lehetőségek a különböző adattípusok közt. Például int --> float; str --> int.
#
# Adat beolvasás és kiíratás a képernyőre: ```input()``` és ```print()```, alapvető formázási konvenciók.

# %% [markdown]
# ## 1.&nbsp;Feladat: Téglalap területe és kerülete

# %% [markdown]
# A ```data``` nevű tuple egy négyzet vagy egy téglalap két oldalának hosszát tartalmazza.
#
# Írjunk egy programot, ami az alábbi információkat írja ki:
#  - "Ez egy négyzet?" kérdés és utána a válasz ```True / False```
#  - A négyszög területe: ...
#  - A négyszög kerülete: ...

# %%
data = (12.0, 23.2)

# %%
#Megoldás

# %% [markdown]
# ## 2.&nbsp;Feladat: Téglalap területe adatbekéréssel

# %% [markdown]
# Írjon egy egyszerű programot, amely bekéri egy téglalap két oldalának hosszát, azaz két pozitív valós számot. A kapott értékeket a program tárolja el egy *oldalak* nevű listában.
#
# Visszajelzésként :
# - Írja ki a megadott adatokat
# - Majd számítsa ki a megadott adatokkal a téglalap területét!
#
# A kiíratásban minden adat 2 tizedesjegy pontossággal jelenjen meg.

# %%
#Megoldás

# %% [markdown]
# ## 3.&nbsp;Feladat: str => lista és fordítva?

# %% [markdown]
# Próbáljuk ki, hogy tudunk-e sztringből karakterek listájába konvetrálni az ismert konverziókból tanulva "természetes módon".
#
# És a vissza irány? Karakter listából lehet újra sztring? Nézzünk utána a ```.join()``` sztring metódus használatának és kísérletezzünk vele.

# %%
#Megoldás

# %% [markdown]
# ## 4.&nbsp;Feladat: Számjegyek vizsgálata

# %% [markdown]
# Vizsgáljuk meg az ```n = 122328887390042``` egész szám számjegyeit!
#
#  - Írjuk ki a 10-es helyiértéken szereplő számjegyet?
#  - Van olyan számjegy, ami egyszer sem szerepel benne? Gyűjtsük ki ezeket!
#
#  (Érdemes lehet egész helyett sztringgé alakítani a számot!)

# %%
n = 122328887390042

# %% [markdown]
# ## 5.&nbsp;Feladat: Háromszögegyenlőtlenség

# %% [markdown]
# Az ```oldalak``` nevű lista három valós számot tartalmaz. El kellene dönteni, hogy szerkeszthető-e ezzel a három adattal háromszög.
#
#  - Egyáltalán lehetnek az adatok oldalhosszak? Azaz mind a hárman pozitív számok?
#  - És a háromszög egyenlőtlenség teljesül? (Bármely két oldal összege nagyobb a harmadiknál.)

# %%
oldalak = [2.0, 3.5, 1.2]

# %%
# Megoldás
